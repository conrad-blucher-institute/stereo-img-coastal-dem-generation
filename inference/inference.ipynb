# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')
import inference as inf
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src import dl
data_loader_training, data_loader_validate, data_loader_test = dl.return_data_loaders(
    batch_size = 1, 
    exp_name = '002'
    )
# Out:
# (34, 5) (11, 5) (11, 5)

# %%
train_pred = inf.predict(data_loader= data_loader_training, exp_name= '002')
valid_pred = inf.predict(data_loader= data_loader_validate, exp_name= '002')
test_pred = inf.predict(data_loader= data_loader_test, exp_name= '002')

# %%
inf.scatter_plot(train_pred, valid_pred, test_pred)

# %%
inf.plot_sample_by_index(test_pred, index = 0)

# %%
inf.plot_sample_by_index(test_pred, index = 1)

# %%
inf.plot_sample_by_index(test_pred, index = 2)

# %%
inf.plot_sample_by_index(test_pred, index = 3)

# %%
inf.plot_sample_by_index(test_pred, index = 4)

# %%
inf.plot_sample_by_index(test_pred, index = 5)

# %%
inf.plot_sample_by_index(test_pred, index = 6)

# %%
inf.plot_sample_by_index(test_pred, index = 7)
